# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data/train_data_week_1_challenge.csv')

# %%
data
# Out:
#       continue_drop student_id gender caste  mathematics_marks  english_marks  \
# 0          continue     s01746      M    BC              0.666          0.468
# 1          continue     s16986      M    BC              0.172          0.420
# 2          continue     s00147      F    BC              0.212          0.601
# 3          continue     s08104      F    ST              0.434          0.611
# 4          continue     s11132      F    SC              0.283          0.478
# 5          continue     s18221      M    BC              0.462          0.450
# 6          continue     s00031      F    BC              0.779          0.701
# 7          continue     s18731      F    SC              0.566          0.495
# 8          continue     s02140      M    BC              0.966          0.806
# 9          continue     s12350      F    BC              0.646          0.804
# 10         continue     s07662      F    BC              0.746          0.669
# ...

# %%
data.columns
# Out:
# Index(['continue_drop', 'student_id', 'gender', 'caste', 'mathematics_marks',
#        'english_marks', 'science_marks', 'science_teacher',
#        'languages_teacher', 'guardian', 'internet', 'school_id',
#        'total_students', 'total_toilets', 'establishment_year'],
#       dtype='object')

# %%
data.shape
# Out:
# (17190, 15)

# %%
data.head()
# Out:
#   continue_drop student_id gender caste  mathematics_marks  english_marks  \
# 0      continue     s01746      M    BC              0.666          0.468
# 1      continue     s16986      M    BC              0.172          0.420
# 2      continue     s00147      F    BC              0.212          0.601
# 3      continue     s08104      F    ST              0.434          0.611
# 4      continue     s11132      F    SC              0.283          0.478
#
#    science_marks  science_teacher  languages_teacher guardian  internet  \
# 0          0.666                7                  6    other      True
# 1          0.172                8                 10   mother     False
# 2          0.212                1                  4   mother     False
# 3          0.434                2                  5   father      True
# 4          0.283                1                 10   mother      True
#
#    school_id  total_students  total_toilets  establishment_year
# ...

# %%
data.tail()
# Out:
#       continue_drop student_id gender caste  mathematics_marks  english_marks  \
# 17185          drop     s10634      M    BC              0.389          0.216
# 17186      continue     s16358      M    BC              0.686          0.830
# 17187      continue     s03789      F    BC              0.390          0.497
# 17188      continue     s06904      F    SC              0.304          0.556
# 17189      continue     s16057      F    SC              0.566          0.495
#
#        science_marks  science_teacher  languages_teacher guardian  internet  \
# 17185          0.389                6                  5   mother      True
# 17186          0.686                2                  0   mother      True
# 17187          0.390                3                  2   mother      True
# 17188          0.304                9                 10   father      True
# 17189          0.566                0                  4   father      True
#
# ...

# %%
data.isnull().sum()
# Out:
# continue_drop           0
# student_id              0
# gender                  0
# caste                   0
# mathematics_marks       0
# english_marks           0
# science_marks           0
# science_teacher         0
# languages_teacher       0
# guardian                0
# internet                0
# school_id               0
# total_students          0
# total_toilets         312
# establishment_year    312
# dtype: int64

# %%
data['total_toilets'].fillna(data['total_toilets'].mean(),inplace=True)
data['establishment_year'].fillna(data['establishment_year'].mean(),inplace=True)
data.isnull().sum()
# Out:
# continue_drop         0
# student_id            0
# gender                0
# caste                 0
# mathematics_marks     0
# english_marks         0
# science_marks         0
# science_teacher       0
# languages_teacher     0
# guardian              0
# internet              0
# school_id             0
# total_students        0
# total_toilets         0
# establishment_year    0
# dtype: int64

# %%
data['student_id'].dtype
# Out:
# dtype('O')

# %%
newdata={"continue_drop":{"continue":1,"drop":0}}

# %%
data.replace(newdata,inplace=True)

# %%
data
# Out:
#        continue_drop student_id  gender  caste  mathematics_marks  \
# 0                  1     s01746       1      0              0.666
# 1                  1     s16986       1      0              0.172
# 2                  1     s00147       0      0              0.212
# 3                  1     s08104       0      3              0.434
# 4                  1     s11132       0      1              0.283
# 5                  1     s18221       1      0              0.462
# 6                  1     s00031       0      0              0.779
# 7                  1     s18731       0      1              0.566
# 8                  1     s02140       1      0              0.966
# 9                  1     s12350       0      0              0.646
# 10                 1     s07662       0      0              0.746
# 11                 1     s01999       0      0              0.542
# 12                 1     s05743       0      1              0.566
# ...

# %%
data.internet=data.internet.astype(int)

# %%
feature=['gender','caste','mathematics_marks','english_marks','science_marks','science_teacher','languages_teacher','guardian','internet','total_students','total_toilets']

# %%
x=data[feature]
y=data.continue_drop

# %%
from sklearn.ensemble import RandomForestRegressor
rforest=RandomForestRegressor()
rforest.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
import seaborn as sns
from seaborn import *
# %matplotlib inline
buetify(figure_width=6)

# %%
selected_feature=['gender','caste','mathematics_marks',"english_marks",'science_marks','science_teacher','guardian','internet']
x1=data[selected_feature]

# %%
x1.columns
# Out:
# Index(['gender', 'caste', 'mathematics_marks', 'english_marks',
#        'science_marks', 'science_teacher', 'guardian', 'internet'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.25,random_state=1234)

# %%
from sklearn.linear_model import LogisticRegression
model_one=LogisticRegression()
model_one.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_predict1=model_one.predict(x_test)

# %%
from sklearn.metrics import f1_score
test_acc=f1_score(y_test,y_predict1)
test_acc
# Out:
# 0.9752026704816403

# %%
from sklearn.metrics import confusion_matrix
value=confusion_matrix(y_test,y_predict1)
value
# Out:
# array([[   0,  208],
#        [   0, 4090]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_predict2=rf.predict(x_test)

# %%
test_acc=f1_score(y_test,y_predict2)
test_acc
# Out:
# 1.0

# %%
value=confusion_matrix(y_test,y_predict2)
value
# Out:
# array([[ 208,    0],
#        [   0, 4090]], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)               # 2. instantiate model
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
y_pred3 = knn.predict(x_test)                      
test_acc  = f1_score(y_test, y_pred3)
print("Test Accuracy: {}" .format(test_acc))
# Out:
# Test Accuracy: 1.0

# %%
testing_data = pd.read_csv('data/test_data_week_1_challenge.csv')
testing_data.head()
# Out:
#   student_id gender caste  mathematics_marks  english_marks  science_marks  \
# 0     s00529      F    BC              0.212          0.601          0.212
# 1     s13519      F    BC              0.511          0.551          0.511
# 2     s01753      M    BC              0.890          0.644          0.890
# 3     s00034      F    BC              0.355          0.373          0.355
# 4     s03027      F    BC              0.691          0.147          0.691
#
#    science_teacher  languages_teacher guardian  internet  school_id  \
# 0                1                  4   mother     False        341
# 1                1                  5   mother      True        329
# 2                2                  2   mother      True        390
# 3                7                  4   mother      True        336
# 4                4                  3   father      True        361
#
#    total_students  total_toilets  establishment_year
# ...

# %%
testdata = {
                "gender":{"F":0,"M":1},
                "caste":{"BC":0,"SC":1,"OC":2,"ST":3},
                "guardian":{"mother":0,"father":1,"other":2,"mixed":3}
               }
testing_data.replace(testdata, inplace=True)
testing_data.internet = testing_data.internet.astype(int)
testing_data.head()

# %%
# dropping less important features
testing_data.drop('total_toilets',axis=1, inplace=True)
testing_dara.drop('total_students',axis=1, inplace=True)
testing_data.drop('student_id',axis=1,inplace=True)
testing_data.drop('school_id',axis=1,inplace=True)
testing_data.drop('establishment_year',axis=1, inplace=True)
testing.head()

# %%
testing_data.columns
# Out:
# Index(['gender', 'caste', 'mathematics_marks', 'english_marks',
#        'science_marks', 'science_teacher', 'languages_teacher', 'guardian',
#        'internet'],
#       dtype='object')

# %%
testing_data.drop('languages_teacher',axis=1,inplace=True)
testing_data
# Out:
#       gender  caste  mathematics_marks  english_marks  science_marks  \
# 0          0      0              0.212          0.601          0.212
# 1          0      0              0.511          0.551          0.511
# 2          1      0              0.890          0.644          0.890
# 3          0      0              0.355          0.373          0.355
# 4          0      0              0.691          0.147          0.691
# 5          1      1              0.366          0.440          0.366
# 6          1      0              0.800          0.513          0.800
# 7          1      0              0.388          0.355          0.388
# 8          1      0              0.456          0.518          0.456
# 9          1      0              0.126          0.260          0.126
# 10         0      0              0.212          0.601          0.212
# 11         0      0              0.346          0.296          0.346
# 12         0      1              0.684          0.848          0.684
# ...

# %%
selfeatures = ['gender', 'caste', 'mathematics_marks', 'english_marks', 'science_marks', 'science_teacher', 'guardian', 'internet']
newdata= testing_data[selfeatures]

# %%
pred = knn.predict(newdata)
result = np.array(pred)                        
result
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
testing_data.columns
# Out:
# Index(['gender', 'caste', 'mathematics_marks', 'english_marks',
#        'science_marks', 'science_teacher', 'guardian', 'internet'],
#       dtype='object')

# %%
np.sav("result.npy")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-9a41ee424126> in <module>()
# ----> 1 np.sav("result.npy")
#
# AttributeError: module 'numpy' has no attribute 'sav'
